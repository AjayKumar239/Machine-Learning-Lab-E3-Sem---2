# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans

# %%
iris = pd.read_csv("Iris.csv")

iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
x = iris.iloc[:,1:5]

x.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0            5.1           3.5            1.4           0.2
# 1            4.9           3.0            1.4           0.2
# 2            4.7           3.2            1.3           0.2
# 3            4.6           3.1            1.5           0.2
# 4            5.0           3.6            1.4           0.2

# %%
# K Means

# Deciding Value of K
# The most crucial aspect of K-Means clustering is deciding the value of K
# We do this by performing Elbow Analysis 




wcss = []
k_values = list(range(1, 10))

for k in k_values:
    kmeans = KMeans(n_clusters=k, max_iter=100)
    kmeans.fit(x)
    wcss.append(kmeans.inertia_)
    print("For cluster = {}, SSE/WCSS is {}".format(k, kmeans.inertia_))

plt.plot(k_values, wcss, marker='o')
plt.title('Elbow Method for Optimal K')
plt.xlabel('Number of clusters (K)')
plt.ylabel('WCSS (Within Cluster Sum of Squares)')
plt.grid(True)
plt.show()
# Out:
# For cluster = 1, SSE/WCSS is 680.8244000000001
# For cluster = 2, SSE/WCSS is 152.36870647733906
# For cluster = 3, SSE/WCSS is 78.94506582597731
# For cluster = 4, SSE/WCSS is 71.348223518285
# For cluster = 5, SSE/WCSS is 46.53558205128205
# For cluster = 6, SSE/WCSS is 42.25234444444445
# For cluster = 7, SSE/WCSS is 35.04275995246583
# For cluster = 8, SSE/WCSS is 32.848631368631374
# For cluster = 9, SSE/WCSS is 30.31320548654245

# %%
# Running K-Means Model

# We now run K-Means clustering for obtaining a 3 cluster solution.


kmeans = KMeans(n_clusters=k, max_iter=100)
kmeans.fit(x)
iris["cluster"] = kmeans.labels_

# %%
iris.sample(10)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 138  139            6.0           3.0            4.8           1.8
# 145  146            6.7           3.0            5.2           2.3
# 115  116            6.4           3.2            5.3           2.3
# 133  134            6.3           2.8            5.1           1.5
# 80    81            5.5           2.4            3.8           1.1
# 66    67            5.6           3.0            4.5           1.5
# 50    51            7.0           3.2            4.7           1.4
# 63    64            6.1           2.9            4.7           1.4
# 125  126            7.2           3.2            6.0           1.8
# 88    89            5.6           3.0            4.1           1.3
#
#              Species  cluster
# 138   Iris-virginica        3
# 145   Iris-virginica        0
# 115   Iris-virginica        0
# 133   Iris-virginica        3
# 80   Iris-versicolor        5
# 66   Iris-versicolor        2
# 50   Iris-versicolor        7
# 63   Iris-versicolor        7
# 125   Iris-virginica        4
# 88   Iris-versicolor        2
